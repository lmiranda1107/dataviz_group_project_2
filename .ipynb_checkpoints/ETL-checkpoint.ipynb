# %% [markdown]
# # ETL Process

# %%
#Dependencies - Modules
import os
import csv

#Dependencies
import pandas as pd
import numpy as np

# %%
#Simple csv reading
'''
csvpath = os.path.join('.', 'Resources', 'ORG_OTC_FCT_DET_reduced.csv')
with open(csvpath, newline='') as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    print(csvreader)

    # Read the header row first (skip this step if there is now header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")

    # Read each row of data after the header
    for row in csvreader:
        print(row)
'''
# Out:
# '\ncsvpath = os.path.join(\'.\', \'Resources\', \'ORG_OTC_FCT_DET_reduced.csv\')\nwith open(csvpath, newline=\'\') as csvfile:\n\n    # CSV reader specifies delimiter and variable that holds contents\n    csvreader = csv.reader(csvfile, delimiter=\',\')\n\n    print(csvreader)\n\n    # Read the header row first (skip this step if there is now header)\n    csv_header = next(csvreader)\n    print(f"CSV Header: {csv_header}")\n\n    # Read each row of data after the header\n    for row in csvreader:\n        print(row)\n'

# %%
#Using pandas to create df
#loading csv - the correct encoding must be used to read the CSV in pandas
file_to_load = "Resources/ORG_OTC_FCT_DET_reduced.csv"
original_organ_transp_data = pd.read_csv(file_to_load,encoding="ISO-8859-1")
#print(original_organ_transp_data.head)

# %%
#Renamed columns to load csv into MySQL - need to use '_' in between spaces
original_organ_transp_data.columns = original_organ_transp_data.columns.str.strip().str.lower().str.replace(' ', '_')
original_organ_transp_data
# Out:
#                  organ_transplantation_type  \
# 0                                    Kidney
# 1                                     Liver
# 2                                     Heart
# 3                                    Kidney
# 4                                  Pancreas
# 5                            Pancreas Islet
# 6                                     Liver
# 7                                 Intestine
# 8                                     Heart
# 9                                      Lung
# 10                                   Kidney
# 11                                    Heart
# 12                                   Kidney
# 13                                    Heart
# 14                                   Kidney
# 15                                    Liver
# 16                                   Kidney
# 17                                    Liver
# 18                                    Heart
# 19                                   Kidney
# 20                                 Pancreas
# 21                                    Liver
# 22                                   Kidney
# 23                                 Pancreas
# 24                                    Liver
# 25                                    Heart
# 26   Vascularized Composite Allograft (VCA)
# 27                                   Kidney
# 28                                    Liver
# 29                                     Lung
# ..                                      ...
# 779                                   Liver
# 780                                  Kidney
# 781                                Pancreas
# 782                                   Liver
# 783                               Intestine
# 784                                   Heart
# 785                                    Lung
# 786  Vascularized Composite Allograft (VCA)
# 787                                  Kidney
# 788                                Pancreas
# 789                                  Kidney
# 790                                   Liver
# 791                                   Heart
# 792                                  Kidney
# 793                                Pancreas
# 794                                   Liver
# 795                                   Heart
# 796                                    Lung
# 797                                  Kidney
# 798                                Pancreas
# 799                                   Liver
# 800                                   Heart
# 801                                  Kidney
# 802                                Pancreas
# 803                          Pancreas Islet
# 804                                   Liver
# 805                               Intestine
# 806                                   Heart
# 807                                    Lung
# 808                                  Kidney
#
#          organ_procurement_organization_name  \
# 0                       Alabama Organ Center
# 1                       Alabama Organ Center
# 2                       Alabama Organ Center
# 3                       Alabama Organ Center
# 4                       Alabama Organ Center
# 5                       Alabama Organ Center
# 6                       Alabama Organ Center
# 7                       Alabama Organ Center
# 8                       Alabama Organ Center
# 9                       Alabama Organ Center
# 10                      Alabama Organ Center
# 11   Arkansas Regional Organ Recovery Agency
# 12   Arkansas Regional Organ Recovery Agency
# 13   Arkansas Regional Organ Recovery Agency
# 14   Arkansas Regional Organ Recovery Agency
# 15   Arkansas Regional Organ Recovery Agency
# 16                  Donor Network of Arizona
# 17                  Donor Network of Arizona
# 18                  Donor Network of Arizona
# 19                  Donor Network of Arizona
# 20                  Donor Network of Arizona
# 21                  Donor Network of Arizona
# 22                  Donor Network of Arizona
# 23                  Donor Network of Arizona
# 24                  Donor Network of Arizona
# 25                  Donor Network of Arizona
# 26                  Donor Network of Arizona
# 27                  Donor Network of Arizona
# 28                  Donor Network of Arizona
# 29                  Donor Network of Arizona
# ..                                       ...
# 779                     LifeCenter Northwest
# 780                     LifeCenter Northwest
# 781                     LifeCenter Northwest
# 782                     LifeCenter Northwest
# 783                     LifeCenter Northwest
# 784                     LifeCenter Northwest
# 785                     LifeCenter Northwest
# 786                     LifeCenter Northwest
# 787                     LifeCenter Northwest
# 788                     LifeCenter Northwest
# 789                  Wisconsin Donor Network
# 790                  Wisconsin Donor Network
# 791                  Wisconsin Donor Network
# 792                  Wisconsin Donor Network
# 793                  Wisconsin Donor Network
# 794                  Wisconsin Donor Network
# 795                  Wisconsin Donor Network
# 796                  Wisconsin Donor Network
# 797                  Wisconsin Donor Network
# 798                  Wisconsin Donor Network
# 799                  Wisconsin Donor Network
# 800                  Wisconsin Donor Network
# 801      UW Health Organ and Tissue Donation
# 802      UW Health Organ and Tissue Donation
# 803      UW Health Organ and Tissue Donation
# 804      UW Health Organ and Tissue Donation
# 805      UW Health Organ and Tissue Donation
# 806      UW Health Organ and Tissue Donation
# 807      UW Health Organ and Tissue Donation
# 808  Center for Organ Recovery and Education
#
#     organ_procurement_organization_city            county          state  \
# 0                            Birmingham  Jefferson County        Alabama
# 1                            Birmingham  Jefferson County        Alabama
# 2                            Birmingham  Jefferson County        Alabama
# 3                            Birmingham  Jefferson County        Alabama
# 4                            Birmingham  Jefferson County        Alabama
# 5                            Birmingham  Jefferson County        Alabama
# 6                            Birmingham  Jefferson County        Alabama
# 7                            Birmingham  Jefferson County        Alabama
# 8                            Birmingham  Jefferson County        Alabama
# 9                            Birmingham  Jefferson County        Alabama
# 10                           Birmingham  Jefferson County        Alabama
# 11                          Little Rock    Pulaski County       Arkansas
# 12                          Little Rock    Pulaski County       Arkansas
# 13                          Little Rock    Pulaski County       Arkansas
# 14                          Little Rock    Pulaski County       Arkansas
# 15                          Little Rock    Pulaski County       Arkansas
# 16                              Phoenix   Maricopa County        Arizona
# 17                              Phoenix   Maricopa County        Arizona
# 18                              Phoenix   Maricopa County        Arizona
# 19                              Phoenix   Maricopa County        Arizona
# 20                              Phoenix   Maricopa County        Arizona
# 21                              Phoenix   Maricopa County        Arizona
# 22                              Phoenix   Maricopa County        Arizona
# 23                              Phoenix   Maricopa County        Arizona
# 24                              Phoenix   Maricopa County        Arizona
# 25                              Phoenix   Maricopa County        Arizona
# 26                              Phoenix   Maricopa County        Arizona
# 27                              Phoenix   Maricopa County        Arizona
# 28                              Phoenix   Maricopa County        Arizona
# 29                              Phoenix   Maricopa County        Arizona
# ..                                  ...               ...            ...
# 779                            Bellevue       King County     Washington
# 780                            Bellevue       King County     Washington
# 781                            Bellevue       King County     Washington
# 782                            Bellevue       King County     Washington
# 783                            Bellevue       King County     Washington
# 784                            Bellevue       King County     Washington
# 785                            Bellevue       King County     Washington
# 786                            Bellevue       King County     Washington
# 787                            Bellevue       King County     Washington
# 788                            Bellevue       King County     Washington
# 789                           Milwaukee  Milwaukee County      Wisconsin
# 790                           Milwaukee  Milwaukee County      Wisconsin
# 791                           Milwaukee  Milwaukee County      Wisconsin
# 792                           Milwaukee  Milwaukee County      Wisconsin
# 793                           Milwaukee  Milwaukee County      Wisconsin
# 794                           Milwaukee  Milwaukee County      Wisconsin
# 795                           Milwaukee  Milwaukee County      Wisconsin
# 796                           Milwaukee  Milwaukee County      Wisconsin
# 797                           Milwaukee  Milwaukee County      Wisconsin
# 798                           Milwaukee  Milwaukee County      Wisconsin
# 799                           Milwaukee  Milwaukee County      Wisconsin
# 800                           Milwaukee  Milwaukee County      Wisconsin
# 801                             Madison       Dane County      Wisconsin
# 802                             Madison       Dane County      Wisconsin
# 803                             Madison       Dane County      Wisconsin
# 804                             Madison       Dane County      Wisconsin
# 805                             Madison       Dane County      Wisconsin
# 806                             Madison       Dane County      Wisconsin
# 807                             Madison       Dane County      Wisconsin
# 808                          Pittsburgh    Kanawha County  West Virginia
#
#     state_abbreviation data_warehouse_record_create_date_text  \
# 0                   AL                               10/25/18
# 1                   AL                               10/25/18
# 2                   AL                               10/25/18
# 3                   AL                               10/25/18
# 4                   AL                               10/25/18
# 5                   AL                               10/25/18
# 6                   AL                               10/25/18
# 7                   AL                               10/25/18
# 8                   AL                               10/25/18
# 9                   AL                               10/25/18
# 10                  AL                               10/25/18
# 11                  AR                               10/25/18
# 12                  AR                               10/25/18
# 13                  AR                               10/25/18
# 14                  AR                               10/25/18
# 15                  AR                               10/25/18
# 16                  AZ                               10/25/18
# 17                  AZ                               10/25/18
# 18                  AZ                               10/25/18
# 19                  AZ                               10/25/18
# 20                  AZ                               10/25/18
# 21                  AZ                               10/25/18
# 22                  AZ                               10/25/18
# 23                  AZ                               10/25/18
# 24                  AZ                               10/25/18
# 25                  AZ                               10/25/18
# 26                  AZ                               10/25/18
# 27                  AZ                               10/25/18
# 28                  AZ                               10/25/18
# 29                  AZ                               10/25/18
# ..                 ...                                    ...
# 779                 WA                               10/25/18
# 780                 WA                               10/25/18
# 781                 WA                               10/25/18
# 782                 WA                               10/25/18
# 783                 WA                               10/25/18
# 784                 WA                               10/25/18
# 785                 WA                               10/25/18
# 786                 WA                               10/25/18
# 787                 WA                               10/25/18
# 788                 WA                               10/25/18
# 789                 WI                               10/25/18
# 790                 WI                               10/25/18
# 791                 WI                               10/25/18
# 792                 WI                               10/25/18
# 793                 WI                               10/25/18
# 794                 WI                               10/25/18
# 795                 WI                               10/25/18
# 796                 WI                               10/25/18
# 797                 WI                               10/25/18
# 798                 WI                               10/25/18
# 799                 WI                               10/25/18
# 800                 WI                               10/25/18
# 801                 WI                               10/25/18
# 802                 WI                               10/25/18
# 803                 WI                               10/25/18
# 804                 WI                               10/25/18
# 805                 WI                               10/25/18
# 806                 WI                               10/25/18
# 807                 WI                               10/25/18
# 808                 WV                               10/25/18
#
#      geocoding__primary_x_coordinate  geocoding_primary_y_coordinate
# 0                         -86.804823                       33.503520
# 1                         -86.804823                       33.503520
# 2                         -86.804823                       33.503520
# 3                         -86.814637                       33.483930
# 4                         -86.814637                       33.483930
# 5                         -86.814637                       33.483930
# 6                         -86.814637                       33.483930
# 7                         -86.814637                       33.483930
# 8                         -86.814637                       33.483930
# 9                         -86.814637                       33.483930
# 10                        -86.801253                       33.505080
# 11                        -92.342479                       34.744983
# 12                        -92.291527                       34.743459
# 13                        -92.291527                       34.743459
# 14                        -92.320745                       34.751489
# 15                        -92.320745                       34.751489
# 16                       -112.040433                       33.480227
# 17                       -112.040433                       33.480227
# 18                       -112.040433                       33.480227
# 19                       -112.056349                       33.464031
# 20                       -112.056349                       33.464031
# 21                       -112.056349                       33.464031
# 22                       -111.954364                       33.662799
# 23                       -111.954364                       33.662799
# 24                       -111.954364                       33.662799
# 25                       -111.954364                       33.662799
# 26                       -111.954364                       33.662799
# 27                       -112.079810                       33.480384
# 28                       -112.079810                       33.480384
# 29                       -112.079810                       33.480384
# ..                               ...                             ...
# 779                      -122.320813                       47.608576
# 780                      -122.307155                       47.650230
# 781                      -122.307155                       47.650230
# 782                      -122.307155                       47.650230
# 783                      -122.307155                       47.650230
# 784                      -122.307155                       47.650230
# 785                      -122.307155                       47.650230
# 786                      -122.307155                       47.650230
# 787                      -122.328257                       47.609414
# 788                      -122.328257                       47.609414
# 789                       -88.024801                       43.038489
# 790                       -88.024801                       43.038489
# 791                       -88.024801                       43.038489
# 792                       -88.028694                       43.038363
# 793                       -88.028694                       43.038363
# 794                       -88.028694                       43.038363
# 795                       -88.028694                       43.038363
# 796                       -88.028694                       43.038363
# 797                       -87.949431                       42.988589
# 798                       -87.949431                       42.988589
# 799                       -87.949431                       42.988589
# 800                       -87.949431                       42.988589
# 801                       -89.429091                       43.075998
# 802                       -89.429091                       43.075998
# 803                       -89.429091                       43.075998
# 804                       -89.429091                       43.075998
# 805                       -89.429091                       43.075998
# 806                       -89.429091                       43.075998
# 807                       -89.429091                       43.075998
# 808                       -81.626170                       38.347152
#
# [809 rows x 9 columns]

# %%
#store csv to lead into mysql
original_organ_transp_data.to_csv('renamed_organ_transp_data.csv')

# %% [markdown]
# # MySQL Process
